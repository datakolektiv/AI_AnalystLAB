# %% [markdown]
# # AI ANALYST LAB
# ### A Hands-on Course on AI for Data Analysts
# ## Session 00: Introduction and Prerequisites
#
# Feedback should be sent to [goran.milovanovic@datakolektiv.com](mailto:goran.milovanovic@datakolektiv.com).
#
# This notebook accompanies the **AI Analyst LAB** course. Session 00 prepares you technically for the rest of the course.

# %% [markdown]
# ### Lecturer
#
# [Goran S. Milovanović, PhD, DataKolektiv, Chief Scientist & Owner](https://www.linkedin.com/in/gmilovanovic/)

# %% [markdown]
# ***
# ### 0. What do we want to do today?
#
# Our goal in Session 00 is to prepare ourselves technically for the rest of the course: install **Python**, set up a **virtual environment** with all the packages we will use, install an editor (**Visual Studio Code**) with Jupyter Notebook support, get the course code from GitHub, and finally verify everything works by running a small machine-learning example at the end of this notebook.
#
# Total time: about **45 minutes** if everything goes smoothly.
#
# #### Roadmap of this notebook
#
# - **0.1, 0.2, 0.3** — install Python, VS Code, and Git on your machine. Pick **only one** section depending on your operating system: **0.1 Windows**, **0.2 macOS**, or **0.3 Ubuntu/Debian Linux**.
# - **0.4** — get the course code from GitHub (same on all operating systems).
# - **0.5** — open this notebook in VS Code (same on all operating systems).
# - **0.6** — what packages we have installed and what each one is for.
# - **Section 1** — a small *smoke test*. If it runs without errors, you are ready for Session 01.
#
# #### Prerequisites: a course directory
#
# Create one directory on your computer that you will use for this course. We will refer to it as your **course directory**. A good name is **`ai_analyst_lab`** (lowercase, no spaces).
#
# Inside `ai_analyst_lab`, create the following sub-directories. We will use them throughout the course to keep things organized:
#
# - `_data` — datasets you will load and analyze
# - `_analytics` — your own scripts and notebooks
# - `_img` — images and plots you save
# - `_reports` — final reports you produce
#
# We recommend placing your course directory directly in your home folder:
#
# - **Windows:** `C:\Users\<your-name>\ai_analyst_lab`
# - **macOS / Linux:** `~/ai_analyst_lab`
#
# > On Windows, your username is the name of the folder under `C:\Users\` that contains your `Documents`, `Downloads`, etc. If unsure, open File Explorer → click **This PC** → **Users**, and look for the folder with your name.

# %% [markdown]
# ***
# #### Important — please read before you start
#
# This notebook is a **recipe**. Follow it from top to bottom, in order, **exactly** as written. Three rules:
#
# 1. **Do not improvise.** If something on your screen does not match what the notebook describes — a different filename, a different button, an unexpected message, a different version number — **stop and contact your instructor**. Do not download a different file, do not skip a step, do not run a "similar" command. Software changes; a single off-script step can leave you with a setup that almost works, which is harder to debug than a setup that clearly does not work.
# 2. **Open every command in a fresh window when the notebook says so.** When we say *"open a NEW PowerShell / Terminal"*, that is because some change (like installing a program) only takes effect in a window opened *after* the change. Re-using an old window is the most common reason "I followed the instructions and it still does not work".
# 3. **Compare your output with the expected output shown in each step.** Each step that runs a command tells you what success looks like. If your output is different, that is the moment to ask for help — not three steps later.
#
# Your instructor will be available throughout the install. If you get stuck for more than a few minutes on any step, just ask.

# %% [markdown]
# #### 0.1 Installations for Windows
#
# > All commands below use **Windows PowerShell**. To open it, type "PowerShell" in the Windows Start menu and click **Windows PowerShell**.
#
# ##### Step 1 — Install Python 3.14.4
#
# We need Python 3.14.4 specifically. The python.org download page has been redesigned and may try to offer you a file called the **Python Install Manager** (`python-manager-*.msix`). That installer is harder for beginners — we will use the **classic installer** instead. Follow the steps below exactly.
#
# 1. Open this link in your browser:
#    [https://www.python.org/downloads/release/python-3144/](https://www.python.org/downloads/release/python-3144/)
# 2. **Ignore any large "Download" button at the top of the page.**
# 3. Scroll **all the way down** the page until you see a heading **"Files"** with a table below it.
# 4. In the Files table, find the row labeled **"Windows installer (64-bit)"**. Click the link in the **"File"** column of that row.
# 5. A file named **`python-3.14.4-amd64.exe`** (about 25–30 MB) will start downloading.
#
# > ⚠️ **Sanity check.** The file you download MUST be named `python-3.14.4-amd64.exe`. If it is named `python-manager-XX.X.msix` instead, you got the wrong installer — go back, scroll further down, and click the **"Windows installer (64-bit)"** row in the Files table.
#
# 6. Open your **Downloads** folder and double-click **`python-3.14.4-amd64.exe`** to run it.
# 7. **CRITICAL — read carefully:** at the bottom of the first installer screen, **tick the checkbox labeled "Add python.exe to PATH"**. Without this, the rest of the course will not work.
# 8. Click **"Install Now"**. The installer takes about a minute.
# 9. When the installer finishes, click **"Disable path length limit"** if offered (this is safe and helpful), then click **"Close"**.
#
# **Verify the installation.** Close any open PowerShell window, then open a **new** PowerShell window (so it picks up the updated PATH). Run:
#
# ```powershell
# python --version
# ```
#
# **Expected output:** `Python 3.14.4`
#
# > If you see a different version (e.g., `Python 3.8.x`), or if you see `'python' is not recognized as an internal or external command`, you most likely missed the "Add python.exe to PATH" checkbox. Re-run the installer, choose **Modify**, tick the box, and re-verify.
#
# ##### Step 2 — Install Visual Studio Code (VS Code)
#
# VS Code is a free, lightweight code editor from Microsoft. It is what we will use to read, edit, and run the course notebooks.
#
# 1. Open [https://code.visualstudio.com/download](https://code.visualstudio.com/download) in your browser.
# 2. Click the **Windows** button to download the installer.
# 3. Run the downloaded `VSCodeUserSetup-x64-*.exe` file.
# 4. Accept the license. Click **Next** through every screen with the **default options**, then **Install**, then **Finish**.
#
# ##### Step 3 — Install the Python and Jupyter extensions in VS Code
#
# Extensions add features to VS Code. We need two of them.
#
# 1. Open VS Code.
# 2. On the left edge of the VS Code window, click the **Extensions** icon (it looks like four squares stacked together).
# 3. In the search bar at the top of the Extensions panel, type **`Python`**. The first result should be **"Python"** published by **Microsoft**. Click the blue **Install** button.
# 4. Now type **`Jupyter`** in the same search bar. The first result should be **"Jupyter"** published by **Microsoft**. Click **Install**. (Companion extensions like *Jupyter Notebook Renderers* will install automatically as dependencies.)
# 5. Close VS Code.
#
# ##### Step 4 — Allow PowerShell to run virtual-environment scripts
#
# By default, Windows PowerShell blocks the activation script we will use in Step 5. We need to allow signed scripts to run *for your user account only* — no administrator rights are required.
#
# In a regular (non-administrator) PowerShell window, run:
#
# ```powershell
# Set-ExecutionPolicy -Scope CurrentUser RemoteSigned
# ```
#
# When asked **"Do you want to change the execution policy?"**, type `Y` and press ENTER.
#
# **Verify:**
#
# ```powershell
# Get-ExecutionPolicy -Scope CurrentUser
# ```
#
# **Expected output:** `RemoteSigned`
#
# ##### Step 5 — Create a Python virtual environment for this course
#
# A *virtual environment* is an isolated, self-contained Python installation that lives inside a folder. We install all course packages **into the virtual environment**, leaving your system Python untouched. This keeps the course setup reproducible and separate from any other Python work you might do.
#
# 1. Open a regular PowerShell window.
# 2. Navigate to your course directory using `cd`. Replace `<your-name>` with your Windows username:
#    ```powershell
#    cd C:\Users\<your-name>\ai_analyst_lab
#    ```
#    > If your Windows username contains a space (e.g., `John Smith`), wrap the path in single quotes:
#    > `cd 'C:\Users\John Smith\ai_analyst_lab'`
# 3. Confirm you are in the right place by running `ls`.
#    **Expected output:** the four sub-directories listed (`_analytics`, `_data`, `_img`, `_reports`).
# 4. Create a virtual environment named **`ailab`**:
#    ```powershell
#    python -m venv ailab
#    ```
#    This takes about 30 seconds and prints nothing on success. When it finishes, run `ls` again — you should now also see an `ailab` folder.
# 5. Activate the virtual environment:
#    ```powershell
#    .\ailab\Scripts\activate
#    ```
#    **Expected output:** your prompt now starts with `(ailab)`. For example:
#    ```
#    (ailab) PS C:\Users\jane\ai_analyst_lab>
#    ```
#
# > **Tip:** to leave the virtual environment, type `deactivate`. To re-enter it next time, navigate back to the course directory and run `.\ailab\Scripts\activate` again.
#
# ##### Step 6 — Install the course packages
#
# While the **`(ailab)`** virtual environment is active (look for `(ailab)` at the start of your prompt — if you do not see it, repeat Step 5), run these two commands one at a time:
#
# ```powershell
# python -m pip install --upgrade pip
# ```
#
# ```powershell
# python -m pip install numpy scipy pandas matplotlib seaborn plotly scikit-learn statsmodels requests ipykernel openai anthropic
# ```
#
# The first command updates pip itself (the Python package installer). The second command installs all course packages and takes **3–5 minutes** — pip downloads many files.
#
# **Expected end-of-output:** the second command should finish with a line like `Successfully installed anthropic-X.X.X numpy-X.X.X openai-X.X.X ...`.
#
# > If the install fails (you see lines starting with `ERROR:`), copy the error message and contact your instructor. Do not try to install packages individually as a workaround — that often makes things worse.
#
# Verify:
#
# ```powershell
# python -m pip list
# ```
#
# You should see a long list including `anthropic`, `numpy`, `openai`, `pandas`, `scikit-learn`, etc.
#
# ##### Step 7 — Install Git for Windows
#
# Git is the version-control system we use to share course code with you. Installing **Git for Windows** also installs **Git Credential Manager**, which we will use in Section 0.4 to authenticate to GitHub.
#
# 1. Open [https://git-scm.com/downloads/win](https://git-scm.com/downloads/win) in your browser.
# 2. Click **64-bit Git for Windows Setup** (under "Standalone Installer") to download the `.exe` file.
# 3. Run the installer. **Click `Next` through every screen with the default options** — there are many screens, but the defaults are correct for our purposes. Finish with **Install**, then **Finish**.
#
# **Verify.** Close any open PowerShell window and open a **new** one (so it picks up the updated PATH). Run:
#
# ```powershell
# git --version
# ```
#
# **Expected output:** something like `git version 2.50.x.windows.1` (any 2.x version is fine).
#
# ✅ **When Step 7 finishes, continue to Section 0.4 below to download the course code from GitHub.**

# %% [markdown]
# #### 0.2 Installations for macOS
#
# > All commands below use the macOS **Terminal**. To open it, press **CMD + SPACE**, type "Terminal", and press ENTER.
#
# ##### Step 1 — Install Homebrew (if you don't already have it)
#
# [Homebrew](https://brew.sh/) is the standard package manager for macOS. We will use it to install Python, Git, and (optionally) VS Code. Installing things via Homebrew makes it easy to update them later.
#
# 1. Check whether you already have Homebrew. In Terminal, run:
#    ```bash
#    brew --version
#    ```
#    - **If you see a version number** (e.g., `Homebrew 4.x.x`), you already have Homebrew — **skip to Step 2**.
#    - **If you see `command not found`**, continue with the steps below.
#
# 2. Install Homebrew by pasting the following command into Terminal and pressing ENTER:
#    ```bash
#    /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
#    ```
# 3. The installer will ask for **your macOS password**. Type it (the characters will not show — that is normal) and press ENTER.
# 4. The installer takes 5–10 minutes. When it finishes, it prints **two `eval` commands** under the heading **"Next steps:"**. **Read this output carefully and run both `eval` commands exactly as printed** — they add `brew` to your PATH so the rest of the steps work.
# 5. Verify:
#    ```bash
#    brew --version
#    ```
#    **Expected output:** something like `Homebrew 4.x.x`.
#
# ##### Step 2 — Install Python 3.14
#
# In Terminal, run:
#
# ```bash
# brew install python@3.14
# ```
#
# This downloads and installs Python 3.14 and takes 2–5 minutes. When it finishes, Homebrew may print a long "Caveats" section telling you about additional setup (e.g., aliases). You can ignore it for now — we will call Python explicitly as `python3.14` everywhere in this notebook.
#
# **Verify:**
#
# ```bash
# python3.14 --version
# ```
#
# **Expected output:** `Python 3.14.x` (any 3.14.x version is fine).
#
# ##### Step 3 — Install Visual Studio Code (VS Code)
#
# You have two equivalent options — pick whichever you prefer.
#
# **Option A — download from the website:**
# 1. Open [https://code.visualstudio.com/download](https://code.visualstudio.com/download) in your browser.
# 2. Click the **Mac** button to download a `.zip` file.
# 3. Open your **Downloads** folder, double-click the `.zip` to extract it, then drag **Visual Studio Code.app** into your **Applications** folder.
#
# **Option B — install via Homebrew:**
# ```bash
# brew install --cask visual-studio-code
# ```
#
# Open VS Code once to confirm it starts. macOS may ask "Are you sure you want to open it?" the first time — click **Open**.
#
# ##### Step 4 — Install the Python and Jupyter extensions in VS Code
#
# 1. Open VS Code.
# 2. On the left edge of the VS Code window, click the **Extensions** icon (it looks like four squares).
# 3. Search for **`Python`** by **Microsoft** and click **Install**.
# 4. Search for **`Jupyter`** by **Microsoft** and click **Install**.
# 5. Close VS Code.
#
# ##### Step 5 — Create a Python virtual environment for this course
#
# A *virtual environment* is an isolated, self-contained Python installation that lives inside a folder. We install all course packages **into the virtual environment**, leaving your system Python untouched.
#
# 1. Open Terminal.
# 2. Navigate to your course directory:
#    ```bash
#    cd ~/ai_analyst_lab
#    ```
# 3. Confirm you are in the right place with `ls`.
#    **Expected output:** the four sub-directories listed (`_analytics`, `_data`, `_img`, `_reports`).
# 4. Create a virtual environment named **`ailab`**:
#    ```bash
#    python3.14 -m venv ailab
#    ```
#    This takes about 30 seconds. When it finishes, `ls` should also show an `ailab` folder.
# 5. Activate the virtual environment:
#    ```bash
#    source ailab/bin/activate
#    ```
#    **Expected output:** your prompt now starts with `(ailab)`. For example:
#    ```
#    (ailab) jane@MacBook ai_analyst_lab %
#    ```
#
# > **Tip:** to leave the virtual environment, type `deactivate`. To re-enter it next time, navigate back to the course directory and run `source ailab/bin/activate` again.
#
# ##### Step 6 — Install the course packages
#
# While the **`(ailab)`** virtual environment is active (look for `(ailab)` at the start of your prompt), run:
#
# ```bash
# python -m pip install --upgrade pip
# ```
#
# ```bash
# python -m pip install numpy scipy pandas matplotlib seaborn plotly scikit-learn statsmodels requests ipykernel openai anthropic
# ```
#
# The second command takes **3–5 minutes**.
#
# **Expected end-of-output:** a line like `Successfully installed anthropic-X.X.X numpy-X.X.X openai-X.X.X ...`.
#
# > If the install fails (lines starting with `ERROR:`), copy the error message and contact your instructor.
#
# Verify:
#
# ```bash
# python -m pip list
# ```
#
# You should see a long list including `anthropic`, `numpy`, `openai`, `pandas`, `scikit-learn`, etc.
#
# ##### Step 7 — Install Git
#
# macOS often comes with Git pre-installed via the Xcode Command Line Tools. We recommend installing the latest version through Homebrew anyway, for consistency:
#
# ```bash
# brew install git
# ```
#
# **Verify:**
#
# ```bash
# git --version
# ```
#
# **Expected output:** something like `git version 2.50.x` (any 2.x version is fine).
#
# ✅ **When Step 7 finishes, continue to Section 0.4 below to download the course code from GitHub.**

# %% [markdown]
# #### 0.3 Installations for Ubuntu / Debian Linux
#
# > All commands below use the Linux **Terminal**. Open it with **CTRL + ALT + T** (or from your application launcher).
#
# ##### Step 1 — Install Python 3.14
#
# Most Linux distributions ship with an older Python by default. To make sure everyone on the course has the same version, we install Python 3.14 from the **deadsnakes** PPA (a trusted community repository).
#
# 1. Update the package index and install prerequisites:
#    ```bash
#    sudo apt update
#    sudo apt install -y software-properties-common
#    ```
#    `sudo` will ask for **your Linux password** (the characters will not show — that is normal).
#
# 2. Add the deadsnakes PPA and install Python 3.14:
#    ```bash
#    sudo add-apt-repository -y ppa:deadsnakes/ppa
#    sudo apt update
#    sudo apt install -y python3.14 python3.14-venv python3.14-dev
#    ```
#
# 3. Verify:
#    ```bash
#    python3.14 --version
#    ```
#    **Expected output:** `Python 3.14.x` (any 3.14.x version is fine).
#
# > **Plain Debian users:** the deadsnakes PPA is Ubuntu-only. If `add-apt-repository` does not work for you, install whatever Python 3 your distribution provides with `sudo apt install python3 python3-venv python3-dev` and contact your instructor — we will help you adapt the rest of the steps.
#
# ##### Step 2 — Install Visual Studio Code (VS Code)
#
# The simplest method on Ubuntu/Debian is to download the `.deb` package from the official website.
#
# 1. Open [https://code.visualstudio.com/download](https://code.visualstudio.com/download) in your browser.
# 2. Click the **`.deb`** button (under the Linux section) to download the file.
# 3. In Terminal, navigate to your `~/Downloads` folder and install the package:
#    ```bash
#    cd ~/Downloads
#    sudo apt install ./code_*.deb
#    ```
#
# **Verify:** open your application launcher and check that **Visual Studio Code** appears.
#
# ##### Step 3 — Install the Python and Jupyter extensions in VS Code
#
# 1. Open VS Code.
# 2. On the left edge of the VS Code window, click the **Extensions** icon (it looks like four squares).
# 3. Search for **`Python`** by **Microsoft** and click **Install**.
# 4. Search for **`Jupyter`** by **Microsoft** and click **Install**.
# 5. Close VS Code.
#
# ##### Step 4 — Create a Python virtual environment for this course
#
# A *virtual environment* is an isolated, self-contained Python installation that lives inside a folder. We install all course packages **into the virtual environment**, leaving your system Python untouched.
#
# 1. Open Terminal.
# 2. Navigate to your course directory:
#    ```bash
#    cd ~/ai_analyst_lab
#    ```
# 3. Confirm you are in the right place with `ls`.
#    **Expected output:** the four sub-directories listed (`_analytics`, `_data`, `_img`, `_reports`).
# 4. Create a virtual environment named **`ailab`**:
#    ```bash
#    python3.14 -m venv ailab
#    ```
#    This takes about 30 seconds.
# 5. Activate the virtual environment:
#    ```bash
#    source ailab/bin/activate
#    ```
#    **Expected output:** your prompt now starts with `(ailab)`. For example:
#    ```
#    (ailab) jane@laptop:~/ai_analyst_lab$
#    ```
#
# > **Tip:** to leave the virtual environment, type `deactivate`. To re-enter it next time, navigate back to the course directory and run `source ailab/bin/activate` again.
#
# ##### Step 5 — Install the course packages
#
# While the **`(ailab)`** virtual environment is active, run:
#
# ```bash
# python -m pip install --upgrade pip
# ```
#
# ```bash
# python -m pip install numpy scipy pandas matplotlib seaborn plotly scikit-learn statsmodels requests ipykernel openai anthropic
# ```
#
# The second command takes **3–5 minutes**.
#
# **Expected end-of-output:** a line like `Successfully installed anthropic-X.X.X numpy-X.X.X openai-X.X.X ...`.
#
# > If the install fails (lines starting with `ERROR:`), copy the error message and contact your instructor.
#
# Verify:
#
# ```bash
# python -m pip list
# ```
#
# ##### Step 6 — Install Git
#
# ```bash
# sudo apt install -y git
# git --version
# ```
#
# **Expected output:** something like `git version 2.x.x`.
#
# ✅ **When Step 6 finishes, continue to Section 0.4 below to download the course code from GitHub.**

# %% [markdown]
# #### 0.4 Get the course code from GitHub
#
# The course code lives in a **private** GitHub repository: [`datakolektiv/AI_AnalystLAB`](https://github.com/datakolektiv/AI_AnalystLAB). To download it onto your computer ("clone" it, in Git terminology), you need three things:
#
# 1. A free **GitHub account**.
# 2. **Access** to the repository — your instructor will invite you by email.
# 3. A **Personal Access Token (PAT)** — a long string that lets Git authenticate as you. We'll create one in this section.
#
# Follow the four sub-steps below in order. Total time: about **5 minutes**.
#
# ---
#
# ##### 0.4.1 Create a GitHub account (skip if you already have one)
#
# 1. Go to [https://github.com/signup](https://github.com/signup) and create a free account.
# 2. Confirm your email address (GitHub will send you a verification email — check your inbox).
# 3. **Tell your instructor your GitHub username** (the short name you chose, *not* your email) so they know who to invite.
#
# ---
#
# ##### 0.4.2 Accept the invitation to the course repository
#
# Your instructor will invite you to the `datakolektiv/AI_AnalystLAB` repository. Once they do:
#
# 1. Check the inbox of the email associated with your GitHub account. You will receive a message from `noreply@github.com`. The subject line looks like **"\[GitHub\] @goranmilovanovic has invited you to..."**.
# 2. Open the email and click the **"View invitation"** button.
# 3. If you are not signed in to GitHub, sign in.
# 4. On the page that opens, click **"Accept invitation"**.
# 5. You should now see the `datakolektiv/AI_AnalystLAB` repository page.
#
# > **Verification.** Open [https://github.com/datakolektiv/AI_AnalystLAB](https://github.com/datakolektiv/AI_AnalystLAB) in your browser while signed in. If the page loads and shows the repository, you have access. If you see "404 — page not found", the invitation has not been accepted yet — go back to step 2, or contact your instructor.
#
# ---
#
# ##### 0.4.3 Generate a Personal Access Token (PAT)
#
# A Personal Access Token is like a password that Git uses on your behalf. We will create a *fine-grained* token that is restricted to **only this one repository** and **only the read permission** — so it is safe to use.
#
# 1. Open this link in your browser: [https://github.com/settings/personal-access-tokens/new](https://github.com/settings/personal-access-tokens/new)
# 2. If GitHub asks you to confirm your identity (a dialog called "Sudo mode"), enter your password.
# 3. Fill in the form **exactly** as follows:
#    - **Token name:** `AI_AnalystLAB-clone` (any descriptive name will do)
#    - **Expiration:** select **90 days** (or longer if you prefer)
#    - **Description:** `For cloning the AI Analyst LAB course repo` (optional)
#    - **Resource owner:** click the dropdown and select **`datakolektiv`**
#    - **Repository access:** click **"Only select repositories"**, then in the new dropdown that appears choose **`datakolektiv/AI_AnalystLAB`**
#    - **Permissions** → expand the **"Repository permissions"** section → scroll down to **"Contents"** → set it to **"Read-only"**
# 4. Click the green **"Generate token"** button at the bottom of the page.
# 5. **A new page appears with your token.** It is a long string starting with `github_pat_…`.
#    - **Copy it immediately** using the small "copy" button next to the token.
#    - **Paste it somewhere safe** — for example, into a temporary text file on your desktop, or into a password manager. **GitHub will not show this token again.** If you lose it, you will have to generate a new one.
#
# ---
#
# ##### 0.4.4 Clone the repository
#
# Now we use the PAT to clone the repository onto your computer.
#
# 1. Open your terminal:
#    - **Windows:** open PowerShell.
#    - **macOS / Linux:** open Terminal.
# 2. Navigate to your course directory. Use the line that matches your operating system:
#
#    **Windows:**
#    ```powershell
#    cd C:\Users\<your-name>\ai_analyst_lab
#    ```
#
#    **macOS / Linux:**
#    ```bash
#    cd ~/ai_analyst_lab
#    ```
#
# 3. Run the clone command (the same on every operating system):
#    ```bash
#    git clone https://github.com/datakolektiv/AI_AnalystLAB.git
#    ```
# 4. Git will prompt you for credentials:
#    - **`Username for 'https://github.com':`** — type your **GitHub username** (the one you chose when signing up — *not* your email address) and press ENTER.
#    - **`Password for 'https://<your-username>@github.com':`** — **paste the PAT** you copied in 0.4.3 and press ENTER.
#
#    > ⚠️ **Important:** when you paste the PAT, the terminal **does not show the characters** — not even dots. That is a security feature, not a bug. Just paste and press ENTER.
# 5. After a few seconds, Git prints something like:
#    ```
#    Cloning into 'AI_AnalystLAB'...
#    remote: Enumerating objects: ...
#    Receiving objects: 100% ...
#    ```
#    When the prompt returns, the clone is finished. Run `ls` (or `dir` on Windows) and confirm that a new **`AI_AnalystLAB`** folder appeared inside your course directory.
#
# ---
#
# ##### 0.4.5 Pulling future updates
#
# Your PAT is now cached on your computer, so Git will not ask for it again. Whenever your instructor adds new course material, run:
#
# ```bash
# cd AI_AnalystLAB
# git pull
# ```
#
# You will get any new files or updates to existing ones.
#
# > The PAT will expire after 90 days (or whatever you chose). When it expires, you will be asked for credentials again — repeat **0.4.3** to generate a fresh token.
#
# ---
#
# ##### Common things that go wrong
#
# - **"Authentication failed"** — most often, this means you typed your *email address* as the username instead of your GitHub *username*, or the token was pasted with extra whitespace. Try the clone again carefully.
# - **"Repository not found" or 404** — you have not accepted the invitation. Go back to **0.4.2**.
# - **A browser window opened asking you to sign in to GitHub** — that is fine, sign in there and let Git Credential Manager finish. The clone should then proceed automatically without asking for the PAT. If that works, you do not strictly need the PAT — but keep it as a backup.

# %% [markdown]
# #### 0.5 Open the course in VS Code and run this notebook
#
# ##### Step 1 — Open the course directory in VS Code
#
# 1. Open VS Code.
# 2. **File → Open Folder** → navigate to your **course directory** (`ai_analyst_lab`) → click **"Select Folder"** (Windows), **"Open"** (macOS), or **"OK"** (Linux).
#    > ⚠️ **Important:** open the **course directory** (`ai_analyst_lab`), *not* the `AI_AnalystLAB` subfolder. The virtual environment lives inside the course directory, and VS Code needs to see it.
# 3. If VS Code asks **"Do you trust the authors of the files in this folder?"**, click **"Yes, I trust the authors"**.
# 4. In the left navigation panel (the file explorer), expand `AI_AnalystLAB` → expand `Session00` → click **`AI_AnalystLAB00.ipynb`** to open this notebook.
#
# ##### Step 2 — Select the Python kernel
#
# The notebook needs to know which Python interpreter to use. We point it at the `ailab` virtual environment we created earlier.
#
# 1. Look at the **upper-right corner of the notebook**. You will see a button that says **"Select Kernel"** (or "Detecting Kernels...").
# 2. Click it. A dropdown appears at the top of VS Code.
# 3. Choose **"Python Environments..."**.
# 4. From the list, select **`ailab`** (it will appear as something like `Python 3.14.4 ('ailab': venv)` or `ailab (Python 3.14.4)`).
#
# > **If you do not see `ailab` in the list:** make sure in the previous step you opened **the course directory** (`ai_analyst_lab`), not the `AI_AnalystLAB` subfolder. Close VS Code and try again.
#
# ##### Step 3 — Run the smoke test
#
# 1. Near the top of the notebook view, click **"Clear All Outputs"**.
# 2. Click **"Run All"**.
# 3. If a popup asks *"Running cells with `ailab` requires the ipykernel package"*, click **"Install"** (we already installed `ipykernel`, but VS Code may want a specific version — go ahead and let it).
# 4. Wait a few seconds for the cells in **Section 1** below to finish running. The progress bar at the side of each running cell turns into a checkmark when it is done.
#
# ✅ **If both the heatmap and the scatter plot in Section 1 render without errors, your environment is fully set up. See you in Session 01!**
#
# If a cell fails, take a screenshot of the error and contact your instructor — do not try to fix it on your own.

# %% [markdown]
# #### 0.6 What packages have we installed?
#
# - [**NumPy**](https://numpy.org/) — adds support for large, multi-dimensional arrays and matrices, plus a large library of high-level math functions. NumPy effectively turns Python into a vector-programming language, similar to R or MATLAB.
#
# - [**Pandas**](https://pandas.pydata.org/) — built on top of NumPy, used for data manipulation, management, and analysis. Pandas adds the `DataFrame` class to Python, which is the essential structure for working with tabular data.
#
# - [**SciPy**](https://scipy.org/) — provides algorithms for optimization, integration, interpolation, eigenvalue problems, algebraic and differential equations, and statistics. The `scipy.stats` module contains the standard probability and statistical functions.
#
# - [**Matplotlib**](https://matplotlib.org/) — the foundational plotting library for Python.
#
# - [**Seaborn**](https://seaborn.pydata.org/) — a higher-level statistical-graphics library built on top of Matplotlib.
#
# - [**Plotly**](https://plotly.com/python/) — an industrial-grade visualization library that produces interactive charts.
#
# - [**statsmodels**](https://www.statsmodels.org/stable/index.html) — classes and functions for the estimation of many different statistical models, plus statistical tests and data exploration.
#
# - [**scikit-learn**](https://scikit-learn.org/stable/) — the standard Python machine-learning library. Contains efficient implementations of most classical ML algorithms.
#
# - [**Requests**](https://requests.readthedocs.io/en/latest/) — the standard HTTP library, used to call APIs and download data from the web.
#
# - [**ipykernel**](https://ipython.readthedocs.io/en/stable/install/kernel_install.html) — provides the kernel that allows Jupyter Notebook (and the VS Code Jupyter extension) to run Python code in our virtual environment.
#
# - [**openai**](https://pypi.org/project/openai/) — official Python SDK for the OpenAI API. We will use it throughout the course to call ChatGPT and other OpenAI models.
#
# - [**anthropic**](https://pypi.org/project/anthropic/) — official Python SDK for the Anthropic API. We will use it throughout the course to call Claude.
#
# > **Note on credentials.** The `openai` and `anthropic` packages let you *call* their APIs, but they do not include API keys. We will set up your API keys in a later session — there is nothing you need to do about credentials right now.

# %% [markdown]
# ### 1. Smoke test: Simple Linear Regression with `scikit-learn`
#
# If your installation went well, the cells below will run from top to bottom without errors. We use the classic **Iris** dataset to fit a tiny linear regression model and draw a chart — just enough to confirm that NumPy, Pandas, scikit-learn, Matplotlib, and Seaborn are all working together.

# %% [markdown]
# Import the packages we need.

# %%
# - packages
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Load the Iris dataset that ships with `scikit-learn`.

# %%
# - data
from sklearn.datasets import load_iris
ds = load_iris()
data_set = pd.DataFrame(data=ds.data, columns=ds.feature_names)
data_set.head(10)

# %% [markdown]
# Inspect the shape of the data — Iris has 150 rows and 4 columns.

# %%
data_set.shape

# %% [markdown]
# Compute pairwise correlations between the four numeric columns.

# %%
data_set.corr(numeric_only=True)

# %% [markdown]
# Visualize the correlation matrix as a heatmap with **Seaborn**.

# %%
# - Seaborn
import seaborn as sns
cor_mat = data_set.corr(numeric_only=True)
plt.figure(figsize=(10, 6))
sns.heatmap(cor_mat, annot=True)
plt.show()

# %% [markdown]
# Confirm the data types of every column.

# %%
data_set.dtypes

# %% [markdown]
# Now fit a **simple linear regression** with `scikit-learn`: predict `petal length (cm)` from `sepal length (cm)`.

# %%
# - numpy + scikit-learn
import numpy as np
from sklearn.linear_model import LinearRegression

# - reshape because we have a single predictor
X = np.array(data_set['sepal length (cm)']).reshape(-1, 1)
y = np.array(data_set['petal length (cm)']).reshape(-1, 1)

# - fit
linear_model = LinearRegression().fit(X, y)

# - report
print("Slope of the regression line:    " + str(linear_model.coef_.item()))
print("Intercept of the regression line: " + str(linear_model.intercept_.item()))

# %% [markdown]
# Visualize the regression line on top of the data.

# %%
plt.figure(figsize=(8, 8))
plt.box(False)
plt.scatter(X, y, color='green', marker='.')
plt.plot(X, linear_model.predict(X), color='blue', linewidth=0.8)
plt.title('Iris: sepal length vs. petal length')
plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.show()

# %% [markdown]
# **If both the heatmap and the scatter plot above rendered without errors, your environment is fully set up. See you in Session 01.**

# %% [markdown]
# <hr>
#
# DataKolektiv, 2026.
#
# [hello@datakolektiv.com](mailto:hello@datakolektiv.com)

# %% [markdown]
# <font size=1>License: [GPLv3](https://www.gnu.org/licenses/gpl-3.0.txt). This Notebook is free software: you can redistribute it and/or modify it under the terms of the GNU General Public License as published by the Free Software Foundation, either version 3 of the License, or (at your option) any later version. This Notebook is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the GNU General Public License for more details.</font>
